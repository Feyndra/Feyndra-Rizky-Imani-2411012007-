# %% [markdown]
# String

# %%
nama = 'Feyndra Rizky Imani'
asal = "Indonesia"

# %%
print(nama)
# Out:
# Feyndra Rizky Imani

# %%
print(asal)
# Out:
# Indonesia

# %% [markdown]
# Manipulasi String

# %%
print(nama, asal)
# Out:
# Feyndra Rizky Imani Indonesia

# %%
print(nama + asal)
# Out:
# Feyndra Rizky ImaniIndonesia

# %%
print("Hallo, nama saya",nama)
# Out:
# Hallo, nama saya Feyndra Rizky Imani

# %%
print("Hallo, nama saya",nama,"asal saya dari",asal)
# Out:
# Hallo, nama saya Feyndra Rizky Imani asal saya dari Indonesia

# %%
data_lengkap = nama + asal

# %%
print (data_lengkap)
# Out:
# Feyndra Rizky ImaniIndonesia

# %% [markdown]
# String + Non String

# %%
asal_kota = "Bandar Lampung"
kode_pos = 35411

asal_kota_kode_pos = asal_kota + str(kode_pos)
print(asal_kota_kode_pos)
# Out:
# Bandar Lampung35411

# %%
asal_kota_x3 = asal_kota * 3
print(asal_kota_x3)
# Out:
# Bandar LampungBandar LampungBandar Lampung
